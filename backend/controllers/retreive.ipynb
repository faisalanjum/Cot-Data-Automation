# %%
import  sys
import pathlib
from DataRetreivalController import DataRetreivalController
import os
from db.models import *
import pandas as pd
# %load_ext dotenv
# %dotenv C:\source\2x4_data\app\data\CommitmentsOfTraders\backend\db\.env

# %%
#object created
obj=DataRetreivalController()

#passing the mapper from the models will return the data from that model class check the models.py file for more details
data=obj.query_data(DisaggregatedFuturesOptions)

# (data)
# Out:
# postgresql://fanjum:3cUDV4jctsfF0pYcxoMQ@pg-prod-master.data-191214.com:5432/lumber-data-sources
# Connection Established!

# %% [markdown]
# # 2 COT tables 1.DisaggregatedFuturesOptions & 2.Legacy

# %%
import pandas as pd
df=pd.DataFrame(data)
df.head()
# Out:
#          Date Open_Interest_All  \
# 0  2022-05-24              2327
# 1  2022-05-17              2278
# 2  2022-05-10              2418
# 3  2022-05-03              2662
# 4  2022-04-26              2781
#
#                            Market_and_Exchange_Names  \
# 0  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 1  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 2  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 3  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 4  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
#
#   CFTC_Contract_Market_Code CFTC_Market_Code CFTC_Region_Code  \
# 0                    058643             CME                 0
# 1                    058643             CME                 0
# 2                    058643             CME                 0
# 3                    058643             CME                 0
# 4                    058643             CME                 0
#
# ...

# %% [markdown]
# Update Code can be found in the following batch file just double click on it and run it
#
# C:\source\2x4_data\app\cron_batches\cot_cron.bat

# %%
df.tail()
# Out:
#             Date Open_Interest_All  \
# 1661  2020-04-21              2663
# 1662  2020-04-14              2752
# 1663  2020-11-17              2906
# 1664  2020-11-10              2723
# 1665  2020-11-03              2648
#
#                               Market_and_Exchange_Names  \
# 1661  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 1662  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 1663  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 1664  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 1665  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
#
#      CFTC_Contract_Market_Code CFTC_Market_Code CFTC_Region_Code  \
# 1661                    058643             CME                 0
# 1662                    058643             CME                 0
# 1663                    058643             CME                 0
# 1664                    058643             CME                 0
# 1665                    058643             CME                 0
#
# ...

# %%
df.sort_values(by=['Date'], ascending=False)
# Out:
#             Date Open_Interest_All  \
# 0     2022-05-24              2327
# 162   2022-05-24              2547
# 170   2022-05-17              2436
# 1     2022-05-17              2278
# 2     2022-05-10              2418
# ...          ...               ...
# 1601  2006-06-27              5760
# 1659  2006-06-20              5457
# 1602  2006-06-20              6027
# 1660  2006-06-13              5568
# 1603  2006-06-13              6095
#
#                               Market_and_Exchange_Names  \
# 0     RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 162   RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 170   RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 1     RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 2     RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# ...                                                 ...
# 1601  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# 1659  RANDOM LENGTH LUMBER - CHICAGO MERCANTILE EXCH...
# ...
